# %% [markdown]
# <a href="https://colab.research.google.com/github/ariyapooh/Webscaping01/blob/main/%E0%B8%AA%E0%B8%B3%E0%B9%80%E0%B8%99%E0%B8%B2%E0%B8%82%E0%B8%AD%E0%B8%87_webscrap_book_excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install azure-storage-blob
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.0/388.0 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.5 MB/s eta 0:00:00
# ...

# %%
pip install bs4
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=6a5cc4f3fe656aa77b8e84e46672a257e6c04edf32243e0ffa40eb8e45a46812
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...

# %%
pip install requests

# %%
pip install pandas

# %% [markdown]
# #openpyxl is a Python library to read/write Excel 2010 xlsx/xlsm/xltx/xltm files. It was born from lack of existing library to read/write natively from Python

# %%
pip install openpyxl

# %%
import pandas as pd
import bs4
import requests
import openpyxl

# %%
item = 1
name_list = []
price_list = []

while item <= 10:
  data = requests.get('https://www.naiin.com/category?type_book=best_seller&product_type_id=1&pageNo=' + str(item))
  soup = bs4.BeautifulSoup(data.text)

  name = soup.find_all('a',{'class':'itemname'})
  price = soup.find_all('p',{'class':'txt-price'})

  for i in name:
    name_list.append(i.text)

  for i in price:
    price_list.append(i.text)

  print('Complete item number: ',item)
  item += 1

table = pd.DataFrame([name_list,price_list]).transpose()
table.columns = ['name','price']
table.set_index('name')
table.to_excel('all bestseller.xlsx',engine='openpyxl') #file is created on google colab cloud
# Out:
# Complete item number:  1
# Complete item number:  2
# Complete item number:  3
# Complete item number:  4
# Complete item number:  5
# Complete item number:  6
# Complete item number:  7
# Complete item number:  8
# Complete item number:  9
# Complete item number:  10

# %% [markdown]
# # *Exercise *
# 1. ให้นักศึกษาทดลองเขียนโปรแกรมเพื่อทำการ scrap ข้อมูลจากเว็บไซต์ https://www.priceza.com/ โดยเลือกรายการสินค้าที่ชอบและบันทึกข้อมูลดังกล่าวในไฟล์ priceza.csv

# %% [markdown]
# # Extract Data from API
# https://github.com/zhiyzuo/python-tutorial/blob/master/5-Getting-Data-Using-APIs.ipynb
#
# https://colab.research.google.com/github/nestauk/im-tutorials/blob/3-ysi-tutorial/notebooks/APIs/API_tutorial.ipynb
#
# https://gist.github.com/SingaramHarish/a61e417f1dc0ab194c82232d45859297
#
# https://home.openweathermap.org/api_keys
# username : wnmk
# pass : Jina0153#

# %%
pip install requests

# %%
import requests

# %%
apikey = '912afa1bb77d67ecdaed434d611a3504'

# %%
weather_url = "https://api.openweathermap.org/data/2.5/weather"
city_name = "Shanghai"
print(weather_url)
print(city_name)
print(apikey)
# Out:
# https://api.openweathermap.org/data/2.5/weather
# Shanghai
# 912afa1bb77d67ecdaed434d611a3504

# %%
r = requests.get(weather_url, params={'q': city_name, 'APPID': apikey})
r.url # `requests` help us encode the URL in the correct format
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?q=Shanghai&APPID=912afa1bb77d67ecdaed434d611a3504'

# %%
r.status_code # 200 means success
# Out:
# 200

# %%
item = 1
name_list = []
price_list = []

while item <= 10:
  data = requests.get('https://www.prettyboygear.com/')
  soup = bs4.BeautifulSoup(data.text)

  name = soup.find_all('div',{'class':'product-name'})
  price = soup.find_all('span',{'class':'product-price-original no-special-price'})

  for i in name:
    name_list.append(i.text.strip('\n').replace(" ", ""))

  for i in price:
    price_list.append(i.text.strip('\n').replace(" ", ""))

  print('Complete item number: ',item)
  item += 1

table = pd.DataFrame([name_list,price_list]).transpose()
table.columns = ['name','price']
table.set_index('name')
table.to_excel('PBG.xlsx',engine='openpyxl') #file is created on google colab cloud
# Out:
# Complete item number:  1
# Complete item number:  2
# Complete item number:  3
# Complete item number:  4
# Complete item number:  5
# Complete item number:  6
# Complete item number:  7
# Complete item number:  8
# Complete item number:  9
# Complete item number:  10

# %%
name_list = []
price_list = []

data = requests.get('https://www.prettyboygear.com/')
soup = bs4.BeautifulSoup(data.text)

for c in soup.find_all("li",{"class" :"product-card"}):
  shirt = c.find("div",{"class" :"product-name"})
  name_list.append(shirt.find('span').text.strip("\n").replace(" ", ""))
  #print(name_list)

  #c.find("div",{"class" :"product-price"})
  price_list.append(c.find("span",{"class" :"product-price-original"}).text.strip("\n").replace(" ", ""))

table = pd.DataFrame([name_list,price_list]).transpose()
table.columns = ['Product_name','price']

table.index +=1

table.to_excel('PBG.xlsx',engine='openpyxl')

# %%
print(len(soup.find_all("li",{"class" :"product-card"})))
# Out:
# 32

# %%
from azure.storage.blob import BlobServiceClient

#ไปที่ storage account แล้วเลือก access key เพื่อ copy key , account และ conection string ใส่ในช่องว่างแต่ละตัวแปร

storage_account_key = "mCqXXtUui5y1nbZM2Jqw+46q8CmkmUDoRFrKgJhKhM6CqKzIqi14TX5m6yI7hh/S+8F0Xu4ZnGU7+ASt9qn5Hw=="
storage_account_name = "bigdataariya"
connection_string = "DefaultEndpointsProtocol=https;AccountName=bigdataariya;AccountKey=mCqXXtUui5y1nbZM2Jqw+46q8CmkmUDoRFrKgJhKhM6CqKzIqi14TX5m6yI7hh/S+8F0Xu4ZnGU7+ASt9qn5Hw==;EndpointSuffix=core.windows.net"
container_name = "blobinsertdata"

#upload file to blobstorage

def uploadToBlobStorage(file_path,file_name):
  blob_service_client = BlobServiceClient.from_connection_string(connection_string)
  blob_client = blob_service_client.get_blob_client(container=container_name,blob=file_name)
  try:
    if blob_client.exists():
        # Delete blob
        blob_client.delete_blob()
        print("Blob deleted successfully!")
    else:
        print("Blob does not exist!")
    with open(file_path,"rb") as data:
      blob_client.upload_blob(data)
    print(f"Uploaded {file_name}.successfully!")
  except Exception as e:
    print("Failed to upload files to container. Error:" + str(e))

uploadToBlobStorage('/content/PBG.xlsx','PBG_Upload.xlsx') #ไฟล์ที่อ่านจาก google drive เพื่อส่งไปยังไฟล์ใน container
# Out:
# Blob does not exist!
# Uploaded PBG_Upload.xlsx.successfully!

# %%
from azure.storage.blob import BlobServiceClient

STORAGEACCOUNTURL = "https://bigdataariya.blob.core.windows.net"
STORAGEACCOUNTKEY = "mCqXXtUui5y1nbZM2Jqw+46q8CmkmUDoRFrKgJhKhM6CqKzIqi14TX5m6yI7hh/S+8F0Xu4ZnGU7+ASt9qn5Hw=="
CONTAINERNAME = "blobinsertdata"
BLOBNAME = "PBG_Upload.xlsx"

blob_service_client_instance = BlobServiceClient(
    account_url=STORAGEACCOUNTURL, credential=STORAGEACCOUNTKEY)

blob_client_instance = blob_service_client_instance.get_blob_client(
    CONTAINERNAME, BLOBNAME, snapshot=None)

blob_data = blob_client_instance.download_blob()
data = blob_data.readall()
print(data)
# Out:
# b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xf4\x80\x0eWFZ\xc1\x0c\x82\x00\x00\x00\xb1\x00\x00\x00\x10\x00\x00\x00docProps/app.xmlM\x8eM\x0b\xc20\x10D\xffJ\xe9\xddnU\xf0 1 \xd4\xa3\xe0\xc9{H76\x90dCv\x85\xfc|S\xc1\x8f\xdb<\xde0\x8c\xba\x15\xcaX\xc4#w5\x86\xc4\xa7~\x11\xc9G\x00\xb6\x0bF\xc3C\xd3\xa9\x19G%\x1aiX\x1e@\xcey\x8b\x13\xd9g\xc4$\xb0\x1b\xc7\x03`\x15L3\xce\x9b\xfc\x1d\xec\xb5:\xe7\x1c\xbc5\xe2)\xe9\xab\xb7\x85\x98\x9ct\x97j1(\xf8\x97k\xf3\x8e\x85\xd7\xbc\x1f\xb6o\xf9a\x05\xbf\x93\xfa\x05PK\x03\x04\x14\x00\x00\x00\x08\x00\xf4\x80\x0eWK\xac\xb1\xb5\xef\x00\x00\x00+\x02\x00\x00\x11\x00\x00\x00docProps/core.xml\xcd\x92QK\xc30\x10\xc7\xbf\x8a\xe4\xbd\xbd\xa4\x1dSB\xd7\x17\xc5\'\x05\xc1\x81\xe2[Hn[X\xd3\x84\xe4\xa4\xdd\xb7\xb7\x8d[\x87\xe8\x07\xf01w\xff\xfc\xeewp\x8d\x0eR\xfb\x88/\xd1\x07\x8cd1\xdd\x8c\xae\xeb\x93\xd4a\xc3\x0eDA\x02$}@\xa7R9%\xfa\xa9\xb9\xf3\xd1)\x9a\x9eq\x0fA\xe9\xa3\xda#T\x9c\xaf\xc1!)\xa3H\xc1\x0c,\xc2Bdmc\xb4\xd4\x11\x15\xf9x\xc6\x1b\xbd\xe0\xc3g\xec2\xcch\xc0\x0e\x1d
# ...

# %%
import os
from multiprocessing.pool import ThreadPool
from azure.storage.blob import BlobServiceClient, BlobClient
from azure.storage.blob import ContentSettings, ContainerClient


MY_CONNECTION_STRING =   "DefaultEndpointsProtocol=https;AccountName=bigdataariya;AccountKey=mCqXXtUui5y1nbZM2Jqw+46q8CmkmUDoRFrKgJhKhM6CqKzIqi14TX5m6yI7hh/S+8F0Xu4ZnGU7+ASt9qn5Hw==;EndpointSuffix=core.windows.net"


MY_BLOB_CONTAINER = "blobinsertdata"


LOCAL_BLOB_PATH = "/content/download_data"

class AzureBlobFileDownloader:
  def init(self):
    print("Intializing AzureBlobFileDownloader")

    self.blob_service_client =  BlobServiceClient.from_connection_string(MY_CONNECTION_STRING)
    self.my_container = self.blob_service_client.get_container_client(MY_BLOB_CONTAINER)

  def download_all_blobs_in_container(self):

    my_blobs = self.my_container.list_blobs()
    result = self.run(my_blobs)
    print(result)

  def run(self,blobs):

    with ThreadPool(processes=int(10)) as pool:
     return pool.map(self.save_blob_locally, blobs)

  def save_blob_locally(self,blob):
    file_name = blob.name
    print(file_name)
    bytes = self.my_container.get_blob_client(blob).download_blob().readall()

    download_file_path = os.path.join(LOCAL_BLOB_PATH, file_name)

    os.makedirs(os.path.dirname(download_file_path), exist_ok=True)

    with open(download_file_path, "wb") as file:
      file.write(bytes)
    return file_name

azure_blob_file_downloader = AzureBlobFileDownloader()
azure_blob_file_downloader.init()
azure_blob_file_downloader.download_all_blobs_in_container()
# Out:
# Intializing AzureBlobFileDownloader
# Ariya.xlsxPBG_Upload.xlsxUnfoundProject.xlsx
#
# stockblob.xlsx
# stocks^GSPC.xlsx
#
# ['Ariya.xlsx', 'PBG_Upload.xlsx', 'UnfoundProject.xlsx', 'stockblob.xlsx', 'stocks^GSPC.xlsx']

# %%
# import pandas lib as pd
import pandas as pd

# read by default 1st sheet of an excel file
dataframe1 = pd.read_excel('/content/download_data/PBG_Upload.xlsx')

dataframe1
# Out:
#     Unnamed: 0                         Product_name      price
# 0            1       NEWERAXPBG59FIFTYFITTED(BLACK)  ฿3,600.00
# 1            2              PBGFCJERSEY(FORESTCAMO)  ฿1,250.00
# 2            3                   PBGFCJERSEY(BLACK)  ฿1,250.00
# 3            4                   PBGFCJERSEY(WHITE)  ฿1,250.00
# 4            5                 NEWLOGOSHORTS(BLACK)  ฿1,050.00
# 5            6                 NEWLOGOBOTTLE(BLACK)    ฿950.00
# 6            7  PRETTYBOYALLOVERPRINTSIDEBAG(BLACK)  ฿1,200.00
# 7            8      PBGLOGORUBBERSHOULDERBAG(BLACK)    ฿900.00
# 8            9            PBGBONETRACKJACKET(BLACK)  ฿1,700.00
# 9           10             PBGBONETRACKPANTS(BLACK)  ฿1,700.00
# 10          11            GOTHICPTRACKPANTS(PURPLE)  ฿1,500.00
# 11          12          GOTHICPTRACKPANTS(BABYBLUE)  ฿1,500.00
# 12          13        BIOHAZARDPVCSHOULDERBAG(PINK)  ฿1,200.00
# 13          14       BIOHAZARDPVCSHOULDERBAG(BLACK)  ฿1,200.00
# ...
